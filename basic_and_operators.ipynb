# %%
print("hello world")
print('hello world')
# Out:
# hello world
# hello world

# %%
print('hello world', end="$")
print('hello ops')
# Out:
# hello world$hello ops

# %% [markdown]
# # to check the datatype of variable

# %%
x=8000
y = "hello"
print(x, type(x) )
print(y,type(y))
# Out:
# 8000 <class 'int'>
# hello <class 'str'>

# %%
address="""area 65/12  society  kendra
jaipur 352142"""

print(address)
# Out:
# area 65/12  society  kendra
# jaipur 352142

# %% [markdown]
# #OPERATORS

# %%
#arithmetic operators
#   +  -  *  / ,//,  % , **
10+2
# Out:
# 12

# %%
25/2
# Out:
# 12.5

# %%
25//2
# Out:
# 12

# %%
5.21+4
# Out:
# 9.21

# %%
2**3
# Out:
# 8

# %%
#OPERATORS PRECEDENCE
# ** , (  * / // ,%),   (  +, -)
3+6*5//3**2
# Out:
# 6

# %%
2*5+8/2-1
# Out:
# 13.0

# %%
# comparison operator
# >  , >=,  <,  <=, !=   ==
10>2
# Out:
# True

# %%
x=102
y=10
x==y
# Out:
# False

# %%
# assignment operator
# +=, -=  ,  *=, //=,   **=,  =
a=19
a=a+5   #a= 19+5
print(a)
# Out:
# 24

# %%
a=19
a/=5        #a=a/5
print(a)
# Out:
# 3.8

# %%
# logical operator
a=1000
a>500  and a>700
# Out:
# True

# %%
a=1000
a>500  and a>7001
# Out:
# False

# %%
a=100
a>500  or a>7001 or a>50
# Out:
# True

# %%
a=100
a>500  or a>700 and a>50
# Out:
# False

# %%
# membership operator
"t" in "tushar"
# Out:
# True

# %%
print( "T" in "tushar" )
# Out:
# False

# %%
#identity  - check the reference of the variable
# use to compare memory address of object

a=190
b=19
print( id(a), id(b) )
a is b
# Out:
# 11648136 11642664
# False

# %% [markdown]
# # STRING FORMATING

# %%
yr=2025
name='paridhi'

print("my name is", name, "year is", yr)
# Out:
# my name is paridhi year is 2025

# %%
"Hello You are %s years %s old." %( yr, name)
# Out:
# 'Hello You are 2025 years paridhi old.'

# %%
print( f"my name is {name} year is {yr}")

#older approach
"my name is {} year is {}".format(name, yr)
# Out:
# my name is paridhi year is 2025
# 'my name is paridhi year is 2025'
